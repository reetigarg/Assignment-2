# %% [markdown]
# # Python Cheat Sheet (Beginner Level)

# %% [markdown]
# ## Introduction
# **Python** is a high-level, beginner-friendly programming language known for its simplicity and readability.
# It is widely used by students to learn basic programming concepts and problem-solving skills.

# %% [markdown]
# ## Key Concepts
# - Simple and readable syntax
# - Uses indentation instead of braces
# - Dynamically typed language
# - Open-source and free to use
# - Large community support

# %% [markdown]
# ## Simple Syntax Examples
# *Minimal code only*

# %%
# Variables
x = 10
name = "Python"

# %%
# Data Types
a = 5
b = 2.5
c = "Hello"

# %%
# Conditional Statement
if a > 3:
    print("Greater than 3")

# %%
# Loop
for i in range(3):
    print(i)

# %%
# List
numbers = [1, 2, 3]

# %% [markdown]
# ## Real-Life or Business Use Case
# Python is used in economics and business studies to:
# 1. Perform basic calculations
# 2. Work with simple datasets
# 3. Apply logical conditions
# 4. Automate repetitive tasks

# %% [markdown]
# ## Advantages
# - Easy to learn for beginners
# - Requires fewer lines of code
# - Large community support
# - Useful in academics and business

# %% [markdown]
# ## Limitations
# - Slower execution speed compared to some languages
# - Not suitable for mobile app development
# - Higher memory usage in some cases

# %% [markdown]
# ## Summary
# A Python cheat sheet acts as a quick reference guide for beginners.
# It helps students revise syntax quickly and understand fundamental programming concepts.
#
# Python is an excellent first language for learning programming.
